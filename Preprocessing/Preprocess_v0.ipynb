# %% [markdown]
# Source : https://datahack.analyticsvidhya.com/contest/query-domain-classification/True/#ProblemStatement

# %%
import pandas as pd
import string
string.punctuation
import re
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
#defining the object for stemming
porter_stemmer = PorterStemmer()

# %%
#defining the object for Lemmatization
wordnet_lemmatizer = WordNetLemmatizer()

# %%
train = pd.read_csv("/content/train_3.csv")
test = pd.read_csv("/content/test_ZUT1mqB.csv")
submission = pd.read_csv("/content/sample_submission_1_mh4j3tR.csv")

# %%
train
# Out:
#         ID                                              Title      Domain
# 0        1  What is good in a decision tree, a large or a ...  Techniques
# 1        2  Training data only contains single positive label  Techniques
# 2        3  Calculating percentage contribution of a negat...  Techniques
# 3        4                   Unable to open solution checker!  Hackathons
# 4        5                                   User Name Change        Misc
# ...    ...                                                ...         ...
# 3840  3841  Where to find practice problems for linear reg...   Resources
# 3841  3842          Running Java code on the GPU with Aparapi       Tools
# 3842  3843  R/Python Script needed to assign Cluster ID to...       Tools
# 3843  3844                  Separate a column into two column  Techniques
# 3844  3845                        Clustering and Segmentation  Techniques
#
# [3845 rows x 3 columns]

# %%
def text_cleaning(text):
  
  punctuationfree = remove_punctuation(text)
  lowered = punctuationfree.lower()
  tokens = tokenization(lowered)
#  nonstop = remove_stopwords(tokens)
  stem_text = stemming(tokens)
  lemm_text = lemmatizer(stem_text)

  return clean_text

# %%
def remove_punctuation(text):

  punctuationfree = "".join([i for i in text if i not in string.punctuation])
  
  return punctuationfree

# %%
def tokenization(text):

  tokens = re.split('W+',text)

  return tokens

# %%
def remove_stopwords(text):

    
    output= [i for i in text if i not in stopwords]
    
    return output

# %%
def stemming(text):
  
  stem_text = [porter_stemmer.stem(word) for word in text]

  return stem_text

# %%
def lemmatizer(text):

  lemm_text = [wordnet_lemmatizer.lemmatize(word) for word in text]
    
  return lemm_text

# %%
train["cleanTitle"] = train.apply(lambda r: 
                            text_cleaning(r["Title"]),
                            axis=1)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/util.py in __load(self)
#      83                 try:
# ---> 84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
#
# /usr/local/lib/python3.8/dist-packages/nltk/data.py in find(resource_name, paths)
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet.zip/wordnet/
#
#   Searched in:
#     - '/root/nltk_data'
# ...

# %%
text = train.loc[0, "Title"]

# %%
remove_punctuation(text)
# Out:
# 'What is good in a decision tree a large or a small leaf size'

# %%
text.lower()
# Out:
# 'what is good in a decision tree, a large or a small leaf size?'
